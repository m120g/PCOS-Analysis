# %% [markdown]
# <div style="background-color: #E75480; border: 2px solid #c48d86; padding: 15px; width: 900px; height: 70px;">
#     <span style="color: #F8F8F8; font-family: Times New Roman; font-size: 35px; white-space: nowrap;">Polycystic Ovary Syndrome [PCOS] Diagnosis</span>
# </div>

# %% [markdown]
# <h1 style="font-size: 1.2em;font-style: italic;">
#     <span style="color: #E75480;">Polycystic Ovary Syndrome (PCOS) is a health problem that affects women of childbearing age. Women with PCOS have a hormonal imbalance and metabolism problems that may affect their overall health.</span>
# </h1>

# %% [markdown]
# <div style="background-color: #E75480; border: 2px solid #c48d86; padding: 15px; width: 300px; height: 53px;">
#     <span style="color: #F8F8F8; font-family: Times New Roman; font-size: 35px; white-space: nowrap;">Table of Contents</span>
# </div>

# %% [markdown]
# **1) Importing Libraries
# <br>2) Ignoring Warnings
# <br>3) Importing the Dataset
# <br>4) Describing the Dataset
# <br>5) Displaying the Dataset
# <br>6) Creating Custom Palettes
# <br>7) Visualizations**

# %% [markdown]
# **Importing essential libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import matplotlib.colors as mcolors
from matplotlib.colors import ListedColormap

# %% [markdown]
# **Ignoring warnings**

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# **Importing the Dataset**

# %%
df=pd.read_csv("C:/MG/PCOS_data.csv")
df.head()
# Out:
#    Sl. No  Patient File No.  PCOS (Y/N)   Age (yrs)  Weight (Kg)  Height(Cm)
# 0       1                 1           0          28         44.6        152.0  \
# 1       2                 2           0          36         65.0        161.5
# 2       3                 3           1          33         68.8        165.0
# 3       4                 4           0          37         65.0        148.0
# 4       5                 5           0          25         52.0        161.0
#
#     BMI  Blood Group  Pulse rate(bpm)   RR (breaths/min)  ...  Pimples(Y/N)
# 0  19.3           15                78                22  ...             0  \
# 1  24.9           15                74                20  ...             0
# 2  25.3           11                72                18  ...             1
# 3  29.7           13                72                20  ...             0
# 4  20.1           11                72                18  ...             0
#
# ...

# %% [markdown]
# **Describing the Data**

# %%
df.describe()
# Out:
#            Sl. No  Patient File No.  PCOS (Y/N)   Age (yrs)  Weight (Kg)
# count  537.000000        537.000000  537.000000  537.000000   537.000000  \
# mean   271.070764        271.070764    0.325885   31.435754    59.680633
# std    156.475961        156.475961    0.469141    5.406608    11.028685
# min      1.000000          1.000000    0.000000   20.000000    31.000000
# 25%    136.000000        136.000000    0.000000   28.000000    52.000000
# 50%    271.000000        271.000000    0.000000   31.000000    59.600000
# 75%    406.000000        406.000000    1.000000   35.000000    65.000000
# max    541.000000        541.000000    1.000000   48.000000   108.000000
#
#        Height(Cm)          BMI  Blood Group  Pulse rate(bpm)
# count   537.000000  537.000000   537.000000        537.000000  \
# mean    156.492171   24.324022    13.800745         73.249534
# std       6.041379    4.058256     1.845567          4.445894
# ...

# %% [markdown]
# **Printing the columns given in the dataset**

# %%
df.columns
# Out:
# Index(['Sl. No', 'Patient File No.', 'PCOS (Y/N)', ' Age (yrs)', 'Weight (Kg)',
#        'Height(Cm) ', 'BMI', 'Blood Group', 'Pulse rate(bpm) ',
#        'RR (breaths/min)', 'Hb(g/dl)', 'Cycle(R/I)', 'Cycle length(days)',
#        'Marraige Status (Yrs)', 'Pregnant(Y/N)', 'No. of abortions',
#        '  I   beta-HCG(mIU/mL)', 'II    beta-HCG(mIU/mL)', 'FSH(mIU/mL)',
#        'LH(mIU/mL)', 'FSH/LH', 'Hip(inch)', 'Waist(inch)', 'Waist:Hip Ratio',
#        'TSH (mIU/L)', 'AMH(ng/mL)', 'PRL(ng/mL)', 'Vit D3 (ng/mL)',
#        'PRG(ng/mL)', 'RBS(mg/dl)', 'Weight gain(Y/N)', 'hair growth(Y/N)',
#        'Skin darkening (Y/N)', 'Hair loss(Y/N)', 'Pimples(Y/N)',
#        'Fast food (Y/N)', 'Reg.Exercise(Y/N)', 'BP _Systolic (mmHg)',
#        'BP _Diastolic (mmHg)', 'Follicle No. (L)', 'Follicle No. (R)',
#        'Avg. F size (L) (mm)', 'Avg. F size (R) (mm)', 'Endometrium (mm)'],
#       dtype='object')

# %% [markdown]
# **Creating custom themed colour palettes for the visualizations**

# %%
pink_palette = ['#FFC0CB', '#FF69B4', '#FF1493', '#FFA07A', '#FF7F50', '#FF6EB4',
                '#FF66CC', '#FF4081', '#F08080', '#E9967A', '#FFB6C1', '#F080A1',
                '#FF9AA2', '#FF8C69', '#DB7093']
sns.set_palette(pink_palette)

# %% [markdown]
# **Defining age-group brackets**

# %%
df.loc[df[' Age (yrs)'].between(0, 15, 'both'), 'Age Group'] = '0-15'
df.loc[df[' Age (yrs)'].between(16, 25, 'both'), 'Age Group'] = '16-25'
df.loc[df[' Age (yrs)'].between(26, 40, 'both'), 'Age Group'] = '26-40'
df.loc[df[' Age (yrs)'].between(41, 65, 'both'), 'Age Group'] = '41-65'
df.loc[df[' Age (yrs)'].between(65, 130, 'both'), 'Age Group'] = '65-130'
df.head()
# Out:
#    Sl. No  Patient File No.  PCOS (Y/N)   Age (yrs)  Weight (Kg)  Height(Cm)
# 0       1                 1           0          28         44.6        152.0  \
# 1       2                 2           0          36         65.0        161.5
# 2       3                 3           1          33         68.8        165.0
# 3       4                 4           0          37         65.0        148.0
# 4       5                 5           0          25         52.0        161.0
#
#     BMI  Blood Group  Pulse rate(bpm)   RR (breaths/min)  ...
# 0  19.3           15                78                22  ...  \
# 1  24.9           15                74                20  ...
# 2  25.3           11                72                18  ...
# 3  29.7           13                72                20  ...
# 4  20.1           11                72                18  ...
#
#    Fast food (Y/N)  Reg.Exercise(Y/N)  BP _Systolic (mmHg)
# 0              1.0                  0                  110  \
# ...

# %% [markdown]
# <div style="background-color: #E75480; border: 2px solid #c48d86; padding: 15px; width: 240px; height: 53px;">
#     <span style="color: #F8F8F8; font-family: Times New Roman; font-size: 35px; white-space: nowrap;">Visualizations</span>
# </div>

# %% [markdown]
# **Countplot of women with PCOS**

# %%
sns.countplot(x='PCOS (Y/N)', data=df, palette=pink_palette)
plt.show()

# %% [markdown]
# *Displays how people who suffer from PCOS are much lesser than the ones that don't. The people who suffer are around 170 and the one's that don't are more than 350.*

# %% [markdown]
# **Boxplots of PCOS diagnosis corresponding to different variables**

# %%
plt.figure(figsize=(20,10))
plt.subplot(1,7,1)
sns.boxplot(x='PCOS (Y/N)',y='Follicle No. (R)',data=df,palette=pink_palette)
plt.subplot(1,7,2)
sns.boxplot(x='PCOS (Y/N)',y='Pulse rate(bpm) ',data=df,palette=pink_palette)
plt.subplot(1,7,3)
sns.boxplot(x='PCOS (Y/N)',y='Follicle No. (L)',data=df,palette=pink_palette)
plt.subplot(1,7,4)
sns.boxplot(x='PCOS (Y/N)',y='Skin darkening (Y/N)',data=df,palette=pink_palette)
plt.subplot(1,7,5)
sns.boxplot(x='PCOS (Y/N)',y='hair growth(Y/N)',data=df,palette=pink_palette)
plt.subplot(1,7,6)
sns.boxplot(x='PCOS (Y/N)',y='Weight gain(Y/N)',data=df,palette=pink_palette)
plt.subplot(1,7,7)
sns.boxplot(x='PCOS (Y/N)',y='Cycle(R/I)',data=df,palette=pink_palette)

plt.show()

# %% [markdown]
# *Displays the range of follicle strength, Pulse Rate, Skin Darkening level, Weight Level and Cycle Regularity corresponding to the PCOS diagnosis.
# <br> PCOS survivors gave a higher follicle number than the ones who don't.
# <br> PCOS survivors have higher cases of their skin darkening if they are diagnosed with it.
# <br> Just like skin darkening, a similar pattern can be seen with respect to the survivors gainibg weight as well.*

# %% [markdown]
# **Histogram of Age Groups**

# %%
fig, ax = plt.subplots()
age_groups = df['Age Group'].unique()
for i, age_group in enumerate(age_groups):
    color = pink_palette[i % len(pink_palette)] 
    sns.histplot(data=df[df['Age Group'] == age_group], x='Age Group', color=color, ax=ax)
plt.title('Histogram by Age Group', fontsize=10)
plt.show()

# %% [markdown]
# *Displays a bar chart of the number of people falling in different age brackets in the dataset, maximum being in the age bracket of 26-40, followed by 16-25 and the least being in 41-65.*

# %%
print(df['PCOS (Y/N)'])
# Out:
# 0      0
# 1      0
# 2      1
# 3      0
# 4      0
#       ..
# 536    0
# 537    0
# 538    0
# 539    0
# 540    1
# Name: PCOS (Y/N), Length: 537, dtype: int64

# %% [markdown]
# **Regression plot of Cycle length corresponding to the Age, marked in hue by whether the person has PCOS or not.**

# %%
color = ["teal", "plum"]
fig=sns.lmplot(data=df,x=" Age (yrs)",y="Cycle length(days)", hue="PCOS (Y/N)",palette=pink_palette)
plt.show(fig)

# %% [markdown]
# *Displays how there is barely any correlation between age and the cycle length, correspondingly shown by the PCOS in hue.*

# %% [markdown]
# **Regression plot of BMI corresponding to the Age, marked in hue by whether the person has PCOS or not.**

# %%
fig= sns.lmplot(data =df,x=" Age (yrs)",y="BMI", hue="PCOS (Y/N)", palette=pink_palette)
plt.show(fig)

# %% [markdown]
# *Shows how there is a slight correlation between BMI and Age. PCOS survivors are known for having a higher BMI due to irregular weight gain phases.*

# %% [markdown]
# **Regression plot of Cycle Regularity corresponding to the Age, marked in hue by whether the person has PCOS or not.**

# %%
sns.lmplot(data =df,x=" Age (yrs)",y="Cycle(R/I)", hue="PCOS (Y/N)",palette=pink_palette)
plt.show()

# %% [markdown]
# *Shows how there is a slight correlation between Cycle and Age. There's a negative correlation between Cycle and Age.*

# %% [markdown]
# **Regression plot of left and right Ovary Follicle, marked in hue by whether the person has PCOS or not.**

# %%
sns.lmplot(data =df,x='Follicle No. (R)',y='Follicle No. (L)', hue="PCOS (Y/N)",palette=pink_palette)
plt.show()

# %% [markdown]
# *Displays how there is a high correlation between left and right follicle of the ovary.*

# %% [markdown]
# **Swarm plot of the left and right follicle marked by whether the person has PCOS or not in hue.**

# %%
features = ["Follicle No. (L)","Follicle No. (R)"]
for i in features:
    sns.swarmplot(x=df["PCOS (Y/N)"], y=df[i], color="black", alpha=0.5 )
    sns.boxenplot(x=df["PCOS (Y/N)"], y=df[i], palette=pink_palette)
    plt.show()

# %% [markdown]
# *Displays how people who have PCOS have a higher number of left and right follicle both than the ones who don't have PCOS. There's barely any outliers in this parameter.*

# %% [markdown]
# **Heatmap of the Dataset**

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# Convert non-numeric values to NaN for all columns
df = df.apply(pd.to_numeric, errors='coerce')

# Drop rows with any NaN values
df = df.dropna()

# Calculate correlation matrix
corrmat = df.corr()

k = 12  # number of variables with positive correlation for heatmap
l = 3   # number of variables with negative correlation for heatmap

cols_p = corrmat.nlargest(k, 'PCOS (Y/N)')['PCOS (Y/N)'].index 
cols_n = corrmat.nsmallest(l, 'PCOS (Y/N)')['PCOS (Y/N)'].index
cols = cols_p.append(cols_n)

cm = np.corrcoef(df[cols].values.T)
sns.set(font_scale=1.25)
plt.figure(figsize=(12, 12))
cmap = ListedColormap(pink_palette)

hm = sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size': 10},
                 yticklabels=cols.values, xticklabels=cols.values,cmap=cmap)
plt.show()

# %% [markdown]
# *Displays the correlation between all the variables present in the dataset. The correlation between the left and righ tfollicle is the highest amongst all.*

# %% [markdown]
# **Barplot of the age- group wise BMI, marked in hue by whether or not they have PCOS.**

# %%
sns.barplot(x='Age Group', y= 'BMI',hue='PCOS (Y/N)', data=df, palette=pink_palette)
# Out:
# <Axes: xlabel='Age Group', ylabel='BMI'>

# %% [markdown]
# *This displays the people who are diagnosed with PCOS have a higher BMI than the ones who don't. The difference remains consistent with the age group.*

# %% [markdown]
# **Swarm plot of PCOS diagnosis corresponding to all the other variables.**

# %%
features = [" Age (yrs)","Weight (Kg)", "BMI", "Hb(g/dl)", "Cycle length(days)","Endometrium (mm)" ]
for i in features:
    sns.swarmplot(x=df["PCOS (Y/N)"], y=df[i], color="black", alpha=0.5 )
    sns.boxenplot(x=df["PCOS (Y/N)"], y=df[i], palette=pink_palette)
    plt.show()

# %% [markdown]
# *Displays how PCOS fall in the age bracket 27-35, the most. They tend to have slightly higher weights than normal, as is the case with BMI as well. Their cycle length is usually not that variant and the rest of the variables remain consistent and don't change with the fact that whether or not the person has PCOS or not.*
